# %% [markdown]
# # This is Python Tutorial

# %% [markdown]
# This is our first program in python: It is just started here

# %%
print("Hellow World")
# Out:
# Hellow World

# %% [markdown]
# $a=b+c$

# %% [markdown]
# # Variables

# %%
x = 3

# %%
# whos will tell us all the variables that are on right now in the memory

# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# st         module    <module 'streamlit' from <...>\streamlit\\__init__.py'>
# x          int       3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x = 5.7

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# st         module    <module 'streamlit' from <...>\streamlit\\__init__.py'>
# x          float     5.7

# %%
print(type(x))
# Out:
# <class 'float'>

# %%
abcd = 556.32

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# abcd       float     556.32
# st         module    <module 'streamlit' from <...>\streamlit\\__init__.py'>
# x          float     5.7

# %%
a,b,c,d,f = 3,5,6.0,7.2,4/3

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# a          int       3
# abcd       float     556.32
# b          int       5
# c          float     6.0
# d          float     7.2
# f          float     1.3333333333333333
# st         module    <module 'streamlit' from <...>\streamlit\\__init__.py'>
# x          float     5.7

# %%
del st

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      3
# b          int      5
# c          float    6.0
# d          float    7.2
# f          float    1.3333333333333333
# x          float    5.7

# %%
print(abcd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ce1394b9d4d9> in <module>
# ----> 1 print(abcd)
#
# NameError: name 'abcd' is not defined

# %%
c = 2+4j

# %%
print(type(c))
# Out:
# <class 'complex'>

# %%
s = "hellow how are you"

# %%
print(type(s))
# Out:
# <class 'str'>

# %% [markdown]
# # Operators

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        3
# b          int        5
# c          complex    (2+4j)
# d          float      7.2
# f          float      1.3333333333333333
# s          str        hellow how are you
# x          float      5.7

# %%
sumOfaAndb = a+b

# %%
print(sumOfaAndb)
# Out:
# 8

# %%
type(sumOfaAndb)
# Out:
# int

# %%
type(a+d)
# Out:
# float

# %%
v = ((a+d)**3)/4

# %%
print(v)
# Out:
# 265.30199999999996

# %%
s1 = "hellow"
s2 = "world"
s = s1+s2
print(s)
# Out:
# hellowworld

# %%
10//3
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %%
_
# Out:
# 3.3333333333333335

# %%
3x = 5
# Out:
#   Cell In[50], line 1
#     3x = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
@y=4
# Out:
#   Cell In[52], line 1
#     @y=4
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
*t=4
# Out:
#   Cell In[53], line 1
#     *t=4
#     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
_e = 6

# %%
startingTimeOfTheCourse = 2.0

# %%
# %whos
# Out:
# Variable                  Type       Data/Info
# ----------------------------------------------
# a                         int        3
# b                         int        5
# c                         complex    (2+4j)
# d                         float      7.2
# f                         float      1.3333333333333333
# s                         str        hellowworld
# s1                        str        hellow
# s2                        str        world
# startingTimeOfTheCourse   float      2.0
# sumOfaAndb                int        8
# v                         float      265.30199999999996
# x                         float      5.7

# %% [markdown]
# # Bool

# %%
a = True
b = True
c = False

# %%
# %whos
# Out:
# Variable                  Type     Data/Info
# --------------------------------------------
# a                         bool     True
# b                         bool     True
# c                         bool     False
# d                         float    7.2
# f                         float    1.3333333333333333
# s                         str      hellowworld
# s1                        str      hellow
# s2                        str      world
# startingTimeOfTheCourse   float    2.0
# sumOfaAndb                int      8
# v                         float    265.30199999999996
# x                         float    5.7

# %%
print(a and b)
print(a and c)
print(c and a)
# Out:
# True
# False
# False

# %%
d = a or c
print(d)
# Out:
# True

# %%
not(a)
# Out:
# False

# %%
not(b)
# Out:
# False

# %%
not(c)
# Out:
# True

# %%
t = not(d)

# %%
type(t)
# Out:
# bool

# %%
print(t)
# Out:
# False

# %%
not((a and b) or (c or d))
# Out:
# False

# %% [markdown]
# # Comparisons

# %%
print(2<3)
# Out:
# True

# %%
c = 2<3
print(type(c))
print(c)
# Out:
# <class 'bool'>
# True

# %%
d = 3==4

# %%
print(d)
# Out:
# False

# %%
3==3.0
# Out:
# True

# %%
x = 4
y = 9
z = 8.3
r = -3

# %%
(x<y) and (z<y) or (r==x)
# Out:
# True

# %%
(r==x) and (x<y) or (z>y)
# Out:
# False

# %%
(True or False) and False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
print((not(2!=3) and True) or (True and False))
# Out:
# False

# %%
round(4.49999999999999999999999,3)
# Out:
# 4.5

# %%
print(round(4.556))
# Out:
# 5

# %%
print(round(4.345))
# Out:
# 4

# %%
print(round(4.556389,3))
# Out:
# 4.556

# %%
divmod(34,9)
# Out:
# (3, 7)

# %%
B = divmod(27,5)

# %%
type(B)
# Out:
# tuple

# %%
print(B)
# Out:
# (5, 2)

# %%
B[0]
# Out:
# 5

# %%
B[1]
# Out:
# 2

# %%
divmod(22,10)
# Out:
# (2, 2)

# %%
G = divmod(34,9)

# %%
type(G)
# Out:
# tuple

# %%
print(G)
# Out:
# (3, 7)

# %%
G[0]
# Out:
# 3

# %%
G[1]
# Out:
# 7

# %%
34//9
# Out:
# 3

# %%
34%9
# Out:
# 7

# %%
isinstance(3,complex)
# Out:
# False

# %%
isinstance(3.4,(float,int))
# Out:
# True

# %%
isinstance(2+3j,(int,float,str,complex))
# Out:
# True

# %%
pow(2,4)
# Out:
# 16

# %%
2**4
# Out:
# 16

# %%
pow(2,4,7)
# Out:
# 2

# %%
pow(2,4,6)
# Out:
# 4

# %%
x = input("Enter a number :")

# %%
type(x)
# Out:
# str

# %%
x = int(x)

# %%
type(x)
# Out:
# int

# %%
print(x-34)
# Out:
# -11

# %%
a = float(input("Enter a real number :"))

# %%
type(a)
# Out:
# float

# %%
b = float(input("Enter a real number : "))

# %%
help(pow)
# Out:
# Help on built-in function pow in module builtins:
#
# pow(base, exp, mod=None)
#     Equivalent to base**exp with 2 arguments or base**exp % mod with 3 arguments
#
#     Some types, such as ints, are able to use a more efficient algorithm when
#     invoked using the three argument form.

# %%
help(input)
# Out:
# Help on method raw_input in module ipykernel.kernelbase:
#
# raw_input(prompt='') method of ipykernel.ipkernel.IPythonKernel instance
#     Forward raw_input to frontends
#
#     Raises
#     ------
#     StdinNotImplentedError if active frontend doesn't support stdin.

# %%
a = int(input())
b = int(input())

if a>b:
    print("a lớn hơn b")
if a<b:
    print("b lớn hơn a")
if a == b:
    print("a and b is", a)
# Out:
# a and b is 0

# %%
a = int(input())
b = int(input())

if a>b:
    print(a)
    print('I am still inside if condition')
print('I am outside if condition')
# Out:
# I am outside if condition

# %%
a = int(input())
b = int(input())
if b>a:
    print('b is greater than a')
else:
    print('b is not greater than a')
# Out:
# b is greater than a

# %%
a = 10
b = 10
if a>b:
    print(a)
    print('if part')
else:
    print(b)
    print('else part')
# Out:
# 10
# else part

# %%
a = int(input('Enter the first number:'))
b = int(input('Enter the second number:'))
if a==b:
    print('Equal')
elif a>b:
    print('a is larger than b')
    print('a =', a)
elif a<b:
    print('a is lower than b')
    print('b =', b)
print('Not in if')
# Out:
# a is lower than b
# b = 101
# Not in if

# %%
a = float(input('Enter Marks:'))
if a >= 17:
    print('A+ Grade')
elif  a< 17 and a >= 15:
    print('A Grade')
elif a<15 and a>= 13:
    print('B+ Grade')
elif a < 13 and a >= 10:
    print('B Grade')
else:
    print('Not Pass')
print('Not in if')
# Out:
# Not Pass
# Not in if

# %%
a = 13
if a>10:
    print(">10")
elif not(a>10):
    print("Else part")
# Out:
# >10

# %%
x = int(input('Enter a number:'))

if x >= 10:
    print('Your number is above ten, ', x)
    if x > 20:
        print('Your number is also above 20')
    else:
        print('Your number is between 10 and 20,', x)
if x > 30:
    print('Your number is also above 30', x)
if x < 10:
    print('Your number is below ten, ', x)
# Out:
# Your number is above ten,  31
# Your number is also above 20
# Your number is also above 30 31

# %%
# single line comment
""" 
User will enter a floating point number let say 238.915. Your task
is to find out the integer portion before the point (in this case 238)

and then check if that integer portion is an even number or not?
"""
from numpy import intp


x = float(input("Enter a real number :"))
y = round(x)

if x > 0:
    if y > x:
        intPortion = y - 1
    else:
        intPortion = y

else:
    if y < x:
        intPortion = y + 1
    else:
        intPortion = y

print(intPortion)
if intPortion%2 ==0:
    print('Even')
else:
    print('Odd')
# Out:
# -7
# Odd

# %%
# i = i + 1; we can write in this way: i+ = 1
n = int(input())

# %%
z = int(input('Max iterations: '))
i = 1

while i < z:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
z = int(input('Max iterations: '))
i = 1
while i < z:
    if i%2 == 0:
        print(i)
    else:
        pass
    i += 1
print('done')
# Out:
# 2
# 4
# 6
# 8
# done

# %%
i = 1
while True:
    if i%5 == 0:
        print('Inside if')
        break
    else:
        i = i + 1
        print('Inside else')
        continue
print('done')
# Out:
# Inside else
# Inside else
# Inside else
# Inside else
# Inside if
# done

# %%
i = 1
while True:
    if i%7 != 0:
        print('inside if', i)
        i +=1
        continue
    print("something", i)
    print("something else")
    break
print("done")
# Out:
# inside if 1
# inside if 2
# inside if 3
# inside if 4
# inside if 5
# inside if 6
# something 7
# something else
# done

# %%
n = 10
i = 1
while True:
    if i%9 != 0:
        print("inside if")
        i +=1
        continue
    print("something")
    print("somethingelse")
    break
    
print("done")
# Out:
# inside if 1
# inside if 2
# inside if 3
# inside if 4
# inside if 5
# inside if 6
# inside if 7
# inside if 8
# something
# somethingelse
# done

# %%
L=[]
for i in range(0,10,4):
    print(i+1)
    L.append(i**2)
print(L)
# Out:
# 1
# 5
# 9
# [0, 16, 64]

# %%
S = {"apple",4.9,"cherry"}
#i = 1
for x in S:
    print(x)
    i+=1
    if i==3:
        break
    else:
        pass
else:
    print("Loop terminates with success")
print("Out side the loop")
# Out:
# cherry
# 4.9
# apple
# Loop terminates with success
# Out side the loop

# %%
D = {"A":10,"B":-19,"C":"abc"}
for x in D:
    print(x,D[x])
# Out:
# A 10
# B -19
# C abc

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""
L = [1,2,4,-5,7,9,3,2]
for j in range(len(L)):
    m = L[j]
    idx = j
    c = j
    for i in range(j, len(L)):
        if L[i] < m:
            m = L[i]
            idx = c
        c+=1
    tmp = L[j]
    L[j] = m
    L[idx] = tmp
L
# Out:
# [-5, 1, 2, 2, 3, 4, 7, 9]

# %%
L = [1,2,4,-5,7,9,3,2]

print(range(len(L)))
# Out:
# range(0, 8)

# %%
print(len(L))
# Out:
# 8

# %%
def printSuccess():
    print("I am done")
    print("send me another task")

# %%
printSuccess()
# Out:
# I am done
# send me another task

# %%
3+8
# Out:
# 11

# %%
printSuccess()
# Out:
# I am done
# send me another task

# %%
def printSuccess2():
    """ This function is doing nothing except printing a message.
    That message is "hellow"
    """ 
    print("hellow")

# %%
help(printSuccess2)
# Out:
# Help on function printSuccess2 in module __main__:
#
# printSuccess2()
#     This function is doing nothing except printing a message.
#     That message is "hellow"

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
printSuccess2()
# Out:
# hellow

# %%
import sys

sys.path.append(r'C:\Users\Thanh Le\Python')

from split_pdf import split_pdf

# %%
help(split_pdf)
# Out:
# Help on function split_pdf in module split_pdf:
#
# split_pdf(input_pdf, start_page, end_page, output_pdf)
#     Splits a range of pages from a PDF.
#
#     Parameters:
#     - input_pdf (str): Path to the source PDF file.
#     - start_page (int): The starting page number (1-indexed).
#     - end_page (int): The ending page number (inclusive).
#     - output_pdf (str): Path to the output PDF file.

# %%
def printMsg(msg):
    """ The function prints the message supplied by the user
    or prints that msg is not in the form of string"""
    
    if isinstance(msg,str):
        print(msg)
    else:
        print("Your input argument is not a string")
        print("Here is the type of what you have supplied :",type(msg))

# %%
help(printMsg)
# Out:
# Help on function printMsg in module __main__:
#
# printMsg(msg)
#     The function prints the message supplied by the user
#     or prints that msg is not in the form of string

# %%
printMsg?
# Out:
# Signature: printMsg(msg)
# Docstring:
# The function prints the message supplied by the user
# or prints that msg is not in the form of string
# File:      c:\users\thanh le\appdata\local\temp\ipykernel_9752\4554208.py
# Type:      function

# %%
printMsg("This is the message")
# Out:
# This is the message

# %%
printMsg(23)
# Out:
# Your input argument is not a string
# Here is the type of what you have supplied : <class 'int'>

# %%
y = "hellow there"
printMsg(y)
# Out:
# hellow there

# %%
def mypow(a,b):
    """ this function computes power just like builtin pow function"""
    c = a**b
    print(c)

# %%
mypow?
# Out:
# Signature: mypow(a, b)
# Docstring: this function computes power just like builtin pow function
# File:      c:\users\thanh le\appdata\local\temp\ipykernel_9752\2046694761.py
# Type:      function

# %%
mypow(3,4)
# Out:
# 81

# %%
3**4
# Out:
# 81

# %%
def checkArgs(a,b,c,d):
    if isinstance(a,(int,float)) and isinstance(b,(int,float)) and isinstance(c,(int,float)) and isinstance(d, (int, float)):
        cal = (a+b+c)**d
    else:
        print("Error: the input arguements are not of the expected types")
    return cal

# %%
checkArgs(3,4,2, 'a')
# Out:
# Error: the input arguements are not of the expected types
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[235], line 1
# ----> 1 checkArgs(3,4,2, 'a')
#
# Cell In[229], line 6, in checkArgs(a, b, c, d)
#       4 else:
#       5     print("Error: the input arguements are not of the expected types")
# ----> 6 return cal
#
# UnboundLocalError: cannot access local variable 'cal' where it is not associated with a value

# %%
checkArgs(3,4,'e', 2)
# Out:
# Error: the input arguements are not of the expected types
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[233], line 1
# ----> 1 checkArgs(3,4,'e', 2)
#
# Cell In[229], line 6, in checkArgs(a, b, c, d)
#       4 else:
#       5     print("Error: the input arguements are not of the expected types")
# ----> 6 return cal
#
# UnboundLocalError: cannot access local variable 'cal' where it is not associated with a value

# %%
checkArgs(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-f6f193ef9e63> in <module>
# ----> 1 checkArgs(3,4)
#
# TypeError: checkArgs() missing 1 required positional argument: 'c'

# %%
checkArgs(2,3,4,5)
# Out:
# 59049

# %%
def f(a,b,c):
    print("A is :",a)
    print("B is :",b)
    print("C is :",c)

# %%
#f(2,3,"game")
f(3,"game",2)
# Out:
# A is : 3
# B is : game
# C is : 2

# %%
#f(a = 2,b=3,c="game")
f(c="game",a=2,b=3)
# Out:
# A is : 2
# B is : 3
# C is : game

# %%
def myadd(a,b):
    sumValue = a+b
    return sumValue

# %%
variableOutSideTheFunction = 3

# %%
def g():
    variableOutSideTheFunction = 5
    #print(variableOutSideTheFunction)

# %%
print(type(g()))
# Out:
# <class 'NoneType'>

# %%
print(variableOutSideTheFunction)
# Out:
# 3

# %%
def h():
    print("A")
    a = 3
    b = 5
    c = a+b
    print("something")
    return c
    print("B")
    print("C")

# %%
print(type(h()))
# Out:
# A
# something
# <class 'int'>

# %%
def r():
    a = 5
    b = 7
    d = "something"
    return a,b,d

# %%
x,y,z = r()
print(x,y,z)
# Out:
# 5 7 something

# %%
def add(*args):
    sum =0
    for i in range(len(args)):
        sum+=args[i]
    return sum

# %%
add(3,4,41)
# Out:
# 48

# %%
def myAddUniversal(*args):
    s = 0
    for i in range(len(args)):
        s += args[i] # s = s+args[i]
    return s

# %%
print(myAddUniversal(2,4,5,4.6,78))
# Out:
# 93.6

# %%
def printAllVariableNamesAndValues(**args):
    for x in args:
        print("Variable Name is :",x," And Value is :",args[x])

# %%
printAllVariableNamesAndValues(a = 3, b = "B",c="CCC",y=6.7)
# Out:
# Variable Name is : a  And Value is : 3
# Variable Name is : b  And Value is : B
# Variable Name is : c  And Value is : CCC
# Variable Name is : y  And Value is : 6.7

# %%
def f(**c):
    for x in c:
        print(x, c[x])

# %%
f(c1 = 'A', c2 = 'B', c3 = 'C')
# Out:
# c1 A
# c2 B
# c3 C

# %%
def gg(s=-1):
    print(s)

# %%
gg()
# Out:
# 4

# %%
gg(56)
# Out:
# 56

# %%
L = [1,2,3]
L2 = L
L2[0] = -9
print(L)
# Out:
# [-9, 2, 3]

# %%
def ff(L=[1,2]):
    for i in L:
        print(i)

# %%
def f(sum = 9):
    print(sum)

# %%
L2 = [12,3,4,5.1,-1]
ff(L2)
# Out:
# 12
# 3
# 4
# 5.1
# -1

# %%
def check_if_not_numeric(*args):
    for i in args:
        if not(isinstance(i, (int, float))):
            return False
    return True

def add_all_numeric(*args):
    s = 0
    for x in args:
        s+=x
    return s

# %%
add_all_numeric??
# Out:
# Signature: add_all_numeric(*args)
# Docstring: <no docstring>
# Source:
# def add_all_numeric(*args):
#     s = 0
#     for x in args:
#         s+=x
#     return s
# File:      c:\users\thanh le\appdata\local\temp\ipykernel_9752\3450944430.py
# Type:      function

# %%
import sys
sys.path.append('C:/ABC/')
import my_universal_functions as myfs
#from my_universal_functions import addAllNumerics

# %%
d = addAllNumerics(2,3,4,5,6,7)
print(d)
# Out:
# 27

# %%
c = myfs.addAllNumerics(2,3,4,6)

# %%
print(c)
# Out:
# 15

# %%
myfs.myName
# Out:
# 'Python Course'

# %%
""" Given a list of numbers i.e. [1,2,4,-5,7,9,3,2], make another list
that contains all the items in sorted order from min to max. i.e. your 
result will be another list like [-5,1,2,2,3,7,9]
"""

def findMin(L): # Find minimum and position of the list
    m = L[0]
    idx = 0
    i = 0
    for x in L:
        if x < m:
            m = x
            idx = i
        else:
            pass
        i+=1
    return m, idx

# %%
a,b = findMin([2,3,4,0,9])
print('min:', a, ', position:', b)
# Out:
# min: 0 , position: 3

# %%
def swapValues(L,idx1,idx2):
    tmp = L[idx1]
    L[idx1] = L[idx2]
    L[idx2] = tmp
    return L

# %%
L = [2,3,6,7]
L2 = swapValues(L,1,3)
print(L2)
# Out:
# [2, 7, 6, 3]

# %%
def sortList(L):
    if not(check_if_not_numeric(L)):
        print("Error: List does not contain numeric values")
        return
    else:
        c = 0
        for x in L:
            m,idx = findMin(L,c)
            L = swapValues(L,c,idx)
            c+=1
    return L

# %%
L2 = sortList([2,1,5,3,-8,17])
print(L2)
# Out:
# [-8, 1, 2, 3, 5, 17]

# %%
checkIfNotNumeric??

# %%
print(checkIfNotNumeric2([2,1,5,3,8,17]))
# Out:
# True

# %%
def checkIfNotNumeric2(L):    
    for x in L:
        if not(isinstance(x,(int,float))):
            return False
    return True

# %%
s = "Python is a good language"
t = "It's good for data science"

# %%
print(type(t))
print(type(s))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print("hellow",12,"hellow2",'who are you',5.9)
# Out:
# hellow 12 hellow2 who are you 5.9

# %%
v = s+". "+t
print(v)
# Out:
# Python is a good language. It's good for data science

# %%
price = 12
s = "The price of this book"
v = s + ' is: ' + str(price)
print(v)
print(s,"is:",price)
# Out:
# The price of this book is: 12
# The price of this book is: 12

# %%
a = """this is line 1
this is line 2
this is last line and this line is 3"""
print(a)
# Out:
# this is line 1
# this is line 2
# this is last line and this line is 3

# %%
print(""" The following options are available:
            -a       : does nothing
            -b       : also does nothing
""")
# Out:
#  The following options are available:
#             -a       : does nothing
#             -b       : also does nothing

# %%
a = "Game of programming"
print(a[3:8])
print(a[-8:-3])

print(len(a))
print(len(a[3:8]))
# Out:
# e of
# gramm
# 19
# 5

# %%
s = "How are you and who are you"
print(s[5])
# Out:
# r

# %%
type(s[5])
# Out:
# str

# %%
s[0:10]
# Out:
# 'How are yo'

# %%
s[-1]
# Out:
# 'u'

# %%
s[-3]
# Out:
# 'y'

# %%
s[-12:-3]
# Out:
# ' who are '

# %%
s[1] = "e" # strings are immutable (unchangeable)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[337], line 1
# ----> 1 s[1] = "e" # strubgs are immutable (unchangeable)
#
# TypeError: 'str' object does not support item assignment

# %%
s
# Out:
# 'How are you and who are you'

# %%
s[::-1]
# Out:
# 'uoy era ohw dna uoy era woH'

# %%
a = "   A lot of    space at the           beginning and end,         "
b = a.strip()
print(b.lower())
print(b.upper())
print(b.replace(",", "."))
# Out:
# a lot of    space at the           beginning and end,
# A LOT OF    SPACE AT THE           BEGINNING AND END,
# A lot of    space at the           beginning and end.

# %%
#s[start:end:step]
s[:12]
# Out:
# 'How are you '

# %%
s[3:]
# Out:
# ' are you and who are you'

# %%
s[1:12]
# Out:
# 'ow are you '

# %%
s[::-1]
# Out:
# 'uoy era ohw dna uoy era woH'

# %%
a = "    abc def     hgq asdfaf     "
b = a.strip()
print(b)
# Out:
# abc def     hgq asdfaf

# %%
a = "ABC deFg ;; sadfa QF"
b = a.lower()
print(b)
# Out:
# abc defg ;; sadfa qf

# %%
c = a.upper()
print(c)
# Out:
# ABC DEFG ;; SADFA QF

# %%
d = a.replace(";","*")
print(d)
# Out:
# ABC deFg ** sadfa QF

# %%
d = a.replace(";","**&&^^%%")
print(d)
# Out:
# ABC deFg **&&^^%%**&&^^%% sadfa QF

# %%
d = a.replace(";;","two semi colons")
print(d)
# Out:
# ABC deFg two semi colons sadfa QF

# %%
a = "abc;def;hgydfa;yy23"
L = a.split(";")
print(L)
# Out:
# ['abc', 'def', 'hgydfa', 'yy23']

# %%
L[1]
# Out:
# 'def'

# %%
print(a.capitalize())
# Out:
# Abc;def;hgydfa;yy23

# %%
"abdAfadfGGQ".capitalize()
# Out:
# 'Abdafadfggq'

# %%
help(a.count)
# Out:
# Help on built-in function count:
#
# count(...) method of builtins.str instance
#     S.count(sub[, start[, end]]) -> int
#
#     Return the number of non-overlapping occurrences of substring sub in
#     string S[start:end].  Optional arguments start and end are
#     interpreted as in slice notation.

# %%
"abc" in "asdfafdjabcl;jfdopasdfoajfd;la"
# Out:
# True

# %%
"abc" == "abc"
# Out:
# True

# %%
"efghiabcd"<"def"
# Out:
# False

# %%
"$%"<"*&"
# Out:
# True

# %%
print("we are learning "string" here")
# Out:
#   Cell In[386], line 1
#     print("we are learning "string" here")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("we are learning \"string\" here")
# Out:
# we are learning "string" here

# %%
print('we are learing "string" here')
# Out:
# we are learing "string" here

# %%
# \n: pushses string into a new line
# \t: inserts a tab into the current line
print("we are \n now on another line")
print("we are \t now on another line")
# Out:
# we are
#  now on another line
# we are 	 now on another line

# %%
print("c:\name\drive")
# Out:
# c:
# ame\drive

# %%
# r means raw string
print(r"c:\name\drive")
# Out:
# c:\name\drive
