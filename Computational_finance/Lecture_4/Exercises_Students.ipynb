# %% [markdown]
# # Random Behaviour of Assets

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Additional Resources

# %% [markdown]
# Aroussi, R. (2019): yfinance, https://pypi.org/project/yfinance/
#
# Github Repository: https://github.com/ranaroussi/yfinance
#
# Smigel, L. (2023): yfinance python tutorial (2023), https://analyzingalpha.com/yfinance-python

# %%
# Import libraries and packages

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# A share has an expected return of 12% per annum (with continuous compounding) and a volatility of 20% per annum. Changes in the share price satisfy $dS = \mu S dt + \sigma S dX$. Simulate the movement of the share price, currently EUR 100, over one year, using a time interval of one week.

# %% [markdown]
# We must simulate a movement of $dS = \frac{12}{100} S \frac{1}{52} + \frac{20}{100} S dX = (\frac{12}{5,200} + \frac{20}{100} dX) S = (0.0023 + 0.20 dX) S$, with a time step of 1/52, where $dX$ is drawn from a normal distribution with mean 0 and variance 1/52.

# %%
# Inputs

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# Using daily share price data, find and plot returns for the asset. What are the mean and standard deviation for the sample you have chosen?

# %%
# Get adjusted closing prices for Microsoft

# %%
# Convert series to pandas dataframe

# %%
# Rename column

# %%
# Plot stock price

# %%
# Calculate returns

## Discrete returns

# %%
# Plot returns

## Discrete returns

# %%
# Plot returns

## Continuous returns

# %%
# Moments of return distribution

## Discrete returns

# %%
# Moments of return distribution

## Continuous returns

# %%
# Plot histogram of returns

## Discrete returns

# %%
# Plot histogram of returns

## Continous returns

# %%
# Plot density of returns

## Discrete returns

# %%
# Plot density of returns

## Continous returns

# %%
# Plot histogram of returns together with normal distribution

## Discrete returns
### Setup range

# %%
# Plot histogram of returns together with normal distribution

## Continuous returns
### Setup range
