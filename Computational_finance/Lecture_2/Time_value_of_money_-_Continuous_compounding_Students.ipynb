# %% [markdown]
# # Time Value of Money - Continuous Compounding

# %%
# Import libraries and packages

# %% [markdown]
# ## Function to Plot Coin Tossing Simulation

# %%
# Effect of increasing number of interest payments per year
