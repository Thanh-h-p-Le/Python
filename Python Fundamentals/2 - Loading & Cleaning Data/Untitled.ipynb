# %%
import yfinance as yf

stock = '^CSGN.SW'
startdate = '2023-03-01'
endate = '2023-03-21'

stock_df = yf.download(stock, start=startdate, end=endate)

print(stock_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ^CSGN.SW: No timezone found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
stock = 'CS'
startdate = '2023-03-01'
endate = '2023-03-21'

stock_df = yf.download(stock, start = startdate, end = endate)

print(stock_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2023-03-01  3.03  3.05  2.97   3.00       3.00   15972100
# 2023-03-02  2.81  2.84  2.70   2.84       2.84   35237900
# 2023-03-03  2.97  3.05  2.95   3.03       3.03   15650600
# 2023-03-06  2.99  3.01  2.96   3.00       3.00   12028100
# 2023-03-07  2.96  2.98  2.89   2.89       2.89   14997600
# 2023-03-08  2.89  2.93  2.88   2.90       2.90   20882700
# 2023-03-09  2.84  2.88  2.75   2.77       2.77   21936700
# 2023-03-10  2.76  2.77  2.61   2.66       2.66   37557700
# 2023-03-13  2.44  2.59  2.38   2.54       2.54   46130200
# 2023-03-14  2.56  2.59  2.46   2.51       2.51   39416400
# 2023-03-15  1.76  2.23  1.75   2.16       2.16  434104000
# 2023-03-16  2.30  2.32  2.11   2.16       2.16  224765200
# 2023-03-17  2.05  2.10  1.94   2.01       2.01  136229600
# 2023-03-20  0.91  1.08  0.90   0.94       0.94  374799600

# %%
stock = 'DBK.DE'
startdate = '2023-03-01'
endate = '2023-03-21'

stock_df = yf.download(stock, start = startdate, end = endate)

print(stock_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2023-03-01  11.840  11.860  11.536  11.592     11.592   8590829
# 2023-03-02  11.546  11.578  11.366  11.446     11.446   7502204
# 2023-03-03  11.484  11.690  11.448  11.668     11.668   6419297
# 2023-03-06  11.716  11.786  11.626  11.768     11.768   6916607
# 2023-03-07  11.788  11.790  11.564  11.586     11.586   7318085
# 2023-03-08  11.510  11.710  11.456  11.636     11.636   6998563
# 2023-03-09  11.630  11.664  11.470  11.514     11.514   4831998
# 2023-03-10  10.928  10.940  10.382  10.668     10.668  35032851
# 2023-03-13  10.700  10.778   9.832  10.148     10.148  34947205
# 2023-03-14  10.084  10.660  10.024  10.582     10.582  18529040
# 2023-03-15  10.494  10.634   9.582   9.603      9.603  31934640
# 2023-03-16  10.094  10.176   9.256   9.479      9.479  30759616
# 2023-03-17   9.546   9.827   9.135   9.334      9.334  30500661
